# %% [markdown]
# ## 1. Import Required Libraries

# %%
# Import standard libraries
import pandas as pd
import numpy as np

# Import our custom dataset loader module
import sys
sys.path.append(r'C:\Users\fabio\OneDrive - GUSCanada\VSCODEGIT\MOOC\DataSets')

import LOADcsvdataset as loadCsvDataSet

# %% [markdown]
# ## 2. Check Available Datasets
#
# Let's first see what CSV files are available in our DataSets folder:

# %%
# List all available CSV datasets
loadCsvDataSet.list_datasets()
# Out:
# 📂 Available CSV datasets in DataSets folder:
#    1. ABC.csv
# 📂 Available CSV datasets in DataSets folder:
#    1. ABC.csv
# ['ABC.csv']

# %% [markdown]
# ## 3. Load Dataset - Main Function
#
# Here's the **main function** you'll use in your notebooks. Just call `loadCsvDataSet('filename.csv')` and it will:
# - Load the CSV from the DataSets folder
# - Display basic information
# - Show first few rows
# - Check for missing values
#
# **Example: Loading research.csv**

# %%
# Load a dataset - replace 'research.csv' with your actual filename
data = loadCsvDataSet.loadCsvDataSet('research.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Load a dataset - replace 'research.csv' with your actual filename
# ----> 2 data = LOADcsvdataset.loadCsvDataSet('research.csv')
#
# AttributeError: module 'LOADcsvdataset' has no attribute 'loadCsvDataSet'

# %% [markdown]
# ## 4. Detailed Dataset Information
#
# If you want more detailed information about your dataset:

# %%
# Get detailed information about the dataset (only run if data loaded successfully)
if data is not None:
    loadCsvDataSet.show_info(data)

# %% [markdown]
# ## 5. Data Cleaning
#
# Quick data cleaning (removes duplicates):

# %%
# Clean the dataset (only run if data loaded successfully)
if data is not None:
    clean_data = loadCsvDataSet.quick_clean(data)
    print(f"\n✅ Cleaned dataset ready for analysis!")

# %% [markdown]
# ## 6. Quick Usage Summary
#
# For daily use in your notebooks, you only need these simple commands:
#
# ```python
# # Import the module (once per notebook)
# import sys
# sys.path.append(r'C:\Users\fabio\OneDrive - GUSCanada\VSCODEGIT\MOOC\Datafunctions')
# import LOADcsvdataset as loadCsvDataSet
#
# # Load any CSV dataset (replace with your filename)
# data = loadCsvDataSet.loadCsvDataSet('your_file.csv')
#
# # Optional: Get more details
# loadCsvDataSet.show_info(data)
#
# # Optional: Clean the data
# clean_data = loadCsvDataSet.quick_clean(data)
# ```
#
# That's it! Your data is ready for analysis. 🚀
